# %%
from evolver import evolve_agat

# %%
first_layer=[(0,1),(1,0),(0,-1),(-1,0)]

# %%
evolve_agat(first_layer)

# %%
evolve_agat(first_layer,min_area=0.1)

# %%
evolve_agat(first_layer,layer_width=0.1)

# %%
evolve_agat([(-1,-1),(-1,1),(0,0),(1,1),(1,-1),(0,0)])
